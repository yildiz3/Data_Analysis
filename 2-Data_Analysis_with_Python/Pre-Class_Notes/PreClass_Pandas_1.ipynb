# %%
import pandas as pd
import numpy as np

# %%
serr= pd.Series([11,21,13,41,15,61])
serr
# Out:
# 0    11
# 1    21
# 2    13
# 3    41
# 4    15
# 5    61
# dtype: int64

# %%
ser=pd.Series(list("clarusway"))
ser
# Out:
# 0    c
# 1    l
# 2    a
# 3    r
# 4    u
# 5    s
# 6    w
# 7    a
# 8    y
# dtype: object

# %%
ser.sort_index(ascending=False)
# Out:
# 8    y
# 7    a
# 6    w
# 5    s
# 4    u
# 3    r
# 2    a
# 1    l
# 0    c
# dtype: object

# %%
ser.sort_values()
# Out:
# 2    a
# 7    a
# 0    c
# 1    l
# 3    r
# 5    s
# 4    u
# 6    w
# 8    y
# dtype: object

# %%
ser.isin(['w'])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# dtype: bool

# %%
ser.keys()
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
ser.values
# Out:
# array(['c', 'l', 'a', 'r', 'u', 's', 'w', 'a', 'y'], dtype=object)

# %%
df=pd.DataFrame (np.arange(1,24,2).reshape(3,4), columns=['var1', 'var2', 'Var3', 'var4'])

# %%
df
# Out:
#    var1  var2  Var3  var4
# 0     1     3     5     7
# 1     9    11    13    15
# 2    17    19    21    23

# %%
df.head(2)
# Out:
#    var1  var2  Var3  var4
# 0     1     3     5     7
# 1     9    11    13    15

# %%
df.tail(2)
# Out:
#    var1  var2  Var3  var4
# 1     9    11    13    15
# 2    17    19    21    23

# %%
df.sample(n=2)
# Out:
#    var1  var2  Var3  var4
# 2    17    19    21    23
# 1     9    11    13    15

# %%
df.shape
# Out:
# (3, 4)

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(np.random.randint(9, size=(5, 4)),
                  index = "A B C D E".split(),
                  columns = "W X Y Z".split())

# %%
df
# Out:
#    W  X  Y  Z
# A  1  6  7  8
# B  4  8  5  0
# C  5  8  1  3
# D  8  3  3  2
# E  8  3  7  0

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.shape
# Out:
# (5, 4)

# %%
df.shape
# Out:
# (5, 4)

# %%
df.size
# Out:
# 20

# %%
df.ndim
# Out:
# 2

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of    W  X  Y  Z
# A  1  6  7  8
# B  4  8  5  0
# C  5  8  1  3
# D  8  3  3  2
# E  8  3  7  0>

# %%
newindx="CA NY WY OR CO".split()

# %%
df["newidx"]=newindx

# %%
df.set_index('newidx')
# Out:
#         W  X  Y  Z
# newidx
# CA      1  6  7  8
# NY      4  8  5  0
# WY      5  8  1  3
# OR      8  3  3  2
# CO      8  3  7  0

# %%
df['X']
# Out:
# A    6
# B    8
# C    8
# D    3
# E    3
# Name: X, dtype: int64

# %%
df.X
# Out:
# A    6
# B    8
# C    8
# D    3
# E    3
# Name: X, dtype: int64

# %%
df.iloc[1,0]
# Out:
# 4

# %%
df.iloc[1,3]
# Out:
# 0

# %%
df.loc['C','Z']
# Out:
# 3

# %%
df[df.W<5]
# Out:
#    W  X  Y  Z newidx
# A  1  6  7  8     CA
# B  4  8  5  0     NY

# %%
people_dict={"first":["Richard", "Robert", "Jason"],
             "last" :["Stone", "Deepdive", "Seaborn"],
             "email": ["richardstone@email.com", "robertdeepdive@email.com", 
                        "jasonseaborn@email.com"]}
df=pd.DataFrame(people_dict)
df
# Out:
#      first      last                     email
# 0  Richard     Stone    richardstone@email.com
# 1   Robert  Deepdive  robertdeepdive@email.com
# 2    Jason   Seaborn    jasonseaborn@email.com

# %% [markdown]
# The DataFrame df has already been created above. What is the code for the output below?
#
# 'robertdeepdive@email.com'

# %%
df.iloc[1,2]
# Out:
# 'robertdeepdive@email.com'

# %%
outside = ['A1','A1','A1','A2','A2','A2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)
np.random.seed(101)
data = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['X','Y'])
data
# Out:
#              X         Y
# A1 1  2.706850  0.628133
#    2  0.907969  0.503826
#    3  0.651118 -0.319318
# A2 1 -0.848077  0.605965
#    2 -2.018168  0.740122
#    3  0.528813 -0.589001

# %% [markdown]
# The Multi-Indexed DataFrame data is given above. How to get the following output?

# %%
data.loc['A1']
# Out:
#           X         Y
# 1  2.706850  0.628133
# 2  0.907969  0.503826
# 3  0.651118 -0.319318

# %%
people_dict={"first":["Richard", "Robert", "Jason"],
             "last" :["Stone", "Deepdive", "Seaborn"],
             "email": ["richardstone@email.com", "robertdeepdive@email.com", 
                        "jasonseaborn@email.com"]}
df=pd.DataFrame(people_dict)
df
# Out:
#      first      last                     email
# 0  Richard     Stone    richardstone@email.com
# 1   Robert  Deepdive  robertdeepdive@email.com
# 2    Jason   Seaborn    jasonseaborn@email.com

# %% [markdown]
# The DataFrame df has already been created above. What is the code for the output below?
#
# 0       Stone
# 1    Deepdive
# 2     Seaborn

# %%
df["last"]
# Out:
# 0       Stone
# 1    Deepdive
# 2     Seaborn
# Name: last, dtype: object

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %% [markdown]
# **The DataFrame data has already been created above. How to select the columns city and age ?**

# %%
data[['city','age']]
# Out:
#       city  age
# 0  Gurgaon   10
# 1    Delhi   22
# 2   Mumbai   13
# 3    Delhi   21
# 4   Mumbai   12
# 5    Delhi   11
# 6   Mumbai   17

# %% [markdown]
# **The DataFrame data has already been created above. How to select the row B with loc method as below?
#
# age                   22
# city               Delhi
# gender                 F
# favourite_color     blue**

# %%
data.loc['B']

# %%
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.shape
# Out:
# (150, 5)

# %%
len(df)
# Out:
# 150

# %%
df.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
df.sepal_length.sum()
# Out:
# 876.5

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-62b65cbffb38> in <module>()
# ----> 1 df.drop()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4141         else:
#    4142             raise ValueError(
# ...

# %%
df = pd.DataFrame(np.arange(12).reshape(3, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df.drop(['B', 'C'], axis=1)
# Out:
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %% [markdown]
# ***The DataFrame data has already been created above. What is the code for the output below? (Try to find the rows where the value of age is greater than or equal to 21.)**

# %%
data[data["age"]>=21]
# Out:
#    age section   city gender favourite_color
# 1   22       B  Delhi      F            blue
# 3   21       B  Delhi      M            pink

# %%
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %% [markdown]
# **The DataFrame data has already been created above. How to add a new column (column new ) using the first two chars of the column city ? The modified DataFrame with the new column is given below.**

# %%
data['new'] = data['city'].str[:2]

# %%
data
# Out:
#    age section     city gender favourite_color new
# 0   10       A  Gurgaon      M             red  Gu
# 1   22       B    Delhi      F            blue  De
# 2   13       C   Mumbai      F          yellow  Mu
# 3   21       B    Delhi      M            pink  De
# 4   12       B   Mumbai      M           black  Mu
# 5   11       A    Delhi      M           green  De
# 6   17       A   Mumbai      F             red  Mu

# %% [markdown]
# **The DataFrame data has already been created above. How to set the column section as the index as below?**

# %%
data.set_index('section', inplace=True)

# %%
data.set_index('section', inplace=True)

# %% [markdown]
# The DataFrame data has already been created above. How to remove the column city ?

# %%
series = pd.Series(('Nik', 'P', 30, 'nik@email.com', 175))

# %%
series
# Out:
# 0              Nik
# 1                P
# 2               30
# 3    nik@email.com
# 4              175
# dtype: object

# %%
dataframe1 = pd.DataFrame([('Nik', 'P', 30, 'nik@email.com', 175), 
                           ('Evan', 'D', 31, 'evan@email.com', 170)],
                         columns=['First Name', 'Last Initial', 'Age', 'Email', 'Weight'])

# %%
dataframe1
# Out:
#   First Name Last Initial  Age           Email  Weight
# 0        Nik            P   30   nik@email.com     175
# 1       Evan            D   31  evan@email.com     170

# %%
dataframe2 = pd.DataFrame({'First Name':['Nik','Evan'],
                          'Last Initial':['P','D'],
                           'Age':[30,31],
                           'Email':['Nik@emial.com','Evan@email.com'],
                           'Weight':[170,175]                                        
                          })

# %%
dataframe2
# Out:
#   First Name Last Initial  Age           Email  Weight
# 0        Nik            P   30   Nik@emial.com     170
# 1       Evan            D   31  Evan@email.com     175

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/women-stem.csv')

# %%
df
# Out:
#     Rank  Major_code                                          Major  \
# 0      1        2419                          PETROLEUM ENGINEERING
# 1      2        2416                 MINING AND MINERAL ENGINEERING
# 2      3        2415                      METALLURGICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5        2418                            NUCLEAR ENGINEERING
# ..   ...         ...                                            ...
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 0              Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df.shape
# Out:
# (76, 9)

# %%
df.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df.tail()
# Out:
#     Rank  Major_code                                          Major  \
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 71  Biology & Life Science   9154   3878   5276    0.576360   33000
# 72                  Health  48491  13487  35004    0.721866   33000
# 73                  Health  33599   7574  26025    0.774577   32400
# 74                  Health  38279   1225  37054    0.967998   28000
# 75  Biology & Life Science   8409   3050   5359    0.637293   26000

# %%
df.tail(1)
# Out:
#     Rank  Major_code    Major          Major_category  Total   Men  Women  \
# 75    76        3609  ZOOLOGY  Biology & Life Science   8409  3050   5359
#
#     ShareWomen  Median
# 75    0.637293   26000

# %%
df.head(3)
# Out:
#    Rank  Major_code                           Major Major_category  Total  \
# 0     1        2419           PETROLEUM ENGINEERING    Engineering   2339
# 1     2        2416  MINING AND MINERAL ENGINEERING    Engineering    756
# 2     3        2415       METALLURGICAL ENGINEERING    Engineering    856
#
#     Men  Women  ShareWomen  Median
# 0  2057    282    0.120564  110000
# 1   679     77    0.101852   75000
# 2   725    131    0.153037   73000

# %%
df.sort_index ().head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df.sort_values(by=["Women"], ascending=True)
# Out:
#     Rank  Major_code                                          Major  \
# 1      2        2416                 MINING AND MINERAL ENGINEERING
# 39    40        4005               MATHEMATICS AND COMPUTER SCIENCE
# 2      3        2415                      METALLURGICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 24    25        2411         GEOLOGICAL AND GEOPHYSICAL ENGINEERING
# ..   ...         ...                                            ...
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 62    63        5098          MULTI-DISCIPLINARY OR GENERAL SCIENCE
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 70    71        3600                                        BIOLOGY
# 26    27        6107                                        NURSING
#
#              Major_category   Total     Men   Women  ShareWomen  Median
# 1               Engineering     756     679      77    0.101852   75000
# ...

# %%
df.sort_values(by=["Women"], ascending=False)
# Out:
#     Rank  Major_code                                          Major  \
# 26    27        6107                                        NURSING
# 70    71        3600                                        BIOLOGY
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 62    63        5098          MULTI-DISCIPLINARY OR GENERAL SCIENCE
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# ..   ...         ...                                            ...
# 24    25        2411         GEOLOGICAL AND GEOPHYSICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 2      3        2415                      METALLURGICAL ENGINEERING
# 39    40        4005               MATHEMATICS AND COMPUTER SCIENCE
# 1      2        2416                 MINING AND MINERAL ENGINEERING
#
#              Major_category   Total     Men   Women  ShareWomen  Median
# 26                   Health  209394   21773  187621    0.896019   48000
# ...

# %%
df.sort_values(by=["Total"], ascending=False)
# Out:
#     Rank  Major_code                                      Major  \
# 70    71        3600                                    BIOLOGY
# 26    27        6107                                    NURSING
# 18    19        2102                           COMPUTER SCIENCE
# 7      8        2414                     MECHANICAL ENGINEERING
# 9     10        2408                     ELECTRICAL ENGINEERING
# ..   ...         ...                                        ...
# 3      4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 2      3        2415                  METALLURGICAL ENGINEERING
# 1      2        2416             MINING AND MINERAL ENGINEERING
# 24    25        2411     GEOLOGICAL AND GEOPHYSICAL ENGINEERING
# 39    40        4005           MATHEMATICS AND COMPUTER SCIENCE
#
#              Major_category   Total     Men   Women  ShareWomen  Median
# 70   Biology & Life Science  280709  111762  168947    0.601858   33400
# ...

# %%
df.sort_values(by=["Rank"], axis=0)
# Out:
#     Rank  Major_code                                          Major  \
# 0      1        2419                          PETROLEUM ENGINEERING
# 1      2        2416                 MINING AND MINERAL ENGINEERING
# 2      3        2415                      METALLURGICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5        2418                            NUCLEAR ENGINEERING
# ..   ...         ...                                            ...
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 0              Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df.isin([0,1])
# Out:
#      Rank  Major_code  Major  Major_category  Total    Men  Women  ShareWomen  \
# 0    True       False  False           False  False  False  False       False
# 1   False       False  False           False  False  False  False       False
# 2   False       False  False           False  False  False  False       False
# 3   False       False  False           False  False  False  False       False
# 4   False       False  False           False  False  False  False       False
# ..    ...         ...    ...             ...    ...    ...    ...         ...
# 71  False       False  False           False  False  False  False       False
# 72  False       False  False           False  False  False  False       False
# 73  False       False  False           False  False  False  False       False
# 74  False       False  False           False  False  False  False       False
# 75  False       False  False           False  False  False  False       False
#
#     Median
# 0    False
# ...

# %%
df.keys()
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Major_category', 'Total', 'Men',
#        'Women', 'ShareWomen', 'Median'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Major_category', 'Total', 'Men',
#        'Women', 'ShareWomen', 'Median'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 2419, 'PETROLEUM ENGINEERING', 'Engineering', 2339, 2057, 282,
#         0.120564344, 110000],
#        [2, 2416, 'MINING AND MINERAL ENGINEERING', 'Engineering', 756,
#         679, 77, 0.101851852, 75000],
#        [3, 2415, 'METALLURGICAL ENGINEERING', 'Engineering', 856, 725,
#         131, 0.153037383, 73000],
#        [4, 2417, 'NAVAL ARCHITECTURE AND MARINE ENGINEERING',
#         'Engineering', 1258, 1123, 135, 0.107313196, 70000],
#        [5, 2418, 'NUCLEAR ENGINEERING', 'Engineering', 2573, 2200, 373,
#         0.144966965, 65000],
#        [6, 2405, 'CHEMICAL ENGINEERING', 'Engineering', 32260, 21239,
#         11021, 0.341630502, 65000],
#        [7, 5001, 'ASTRONOMY AND ASTROPHYSICS', 'Physical Sciences', 1792,
#         832, 960, 0.535714286, 62000],
#        [8, 2414, 'MECHANICAL ENGINEERING', 'Engineering', 91227, 80320,
#         10907, 0.119558903, 60000],
#        [9, 2401, 'AEROSPACE ENGINEERING', 'Engineering', 15058, 12953,
# ...

# %%
df.values[5:10]
# Out:
# array([[6, 2405, 'CHEMICAL ENGINEERING', 'Engineering', 32260, 21239,
#         11021, 0.341630502, 65000],
#        [7, 5001, 'ASTRONOMY AND ASTROPHYSICS', 'Physical Sciences', 1792,
#         832, 960, 0.535714286, 62000],
#        [8, 2414, 'MECHANICAL ENGINEERING', 'Engineering', 91227, 80320,
#         10907, 0.119558903, 60000],
#        [9, 2401, 'AEROSPACE ENGINEERING', 'Engineering', 15058, 12953,
#         2105, 0.139792801, 60000],
#        [10, 2408, 'ELECTRICAL ENGINEERING', 'Engineering', 81527, 65511,
#         16016, 0.196450256, 60000]], dtype=object)

# %%
df.sample(n=3)
# Out:
#     Rank  Major_code                               Major  \
# 27    28        2503  INDUSTRIAL PRODUCTION TECHNOLOGIES
# 26    27        6107                             NURSING
# 68    69        3699               MISCELLANEOUS BIOLOGY
#
#             Major_category   Total    Men   Women  ShareWomen  Median
# 27             Engineering    4631   3477    1154    0.249190   46000
# 26                  Health  209394  21773  187621    0.896019   48000
# 68  Biology & Life Science   10706   4747    5959    0.556604   33500

# %%
df.sample(n=5)
# Out:
#     Rank  Major_code                                      Major  \
# 12    13        2404                     BIOMEDICAL ENGINEERING
# 3      4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 48    49        3603                          MOLECULAR BIOLOGY
# 14    15        2402                     BIOLOGICAL ENGINEERING
# 32    33        3701                        APPLIED MATHEMATICS
#
#              Major_category  Total   Men  Women  ShareWomen  Median
# 12              Engineering  14955  8407   6548    0.437847   60000
# 3               Engineering   1258  1123    135    0.107313   70000
# 48   Biology & Life Science  18300  7426  10874    0.594208   40000
# 14              Engineering   8925  6062   2863    0.320784   57100
# 32  Computers & Mathematics   4939  2794   2145    0.434298   45000
