# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.title ("Weather")
plt.plot(x,y, color = "green", linewidth = 5, linestyle = ':' );

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(x,y,'b+--')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(x,y,'rD--');

# %%
plt.plot(x,y,color='blue',marker='+',linestyle='');

# %% [markdown]
# # markersize

# %%
plt.plot(x,y,color='blue',marker='+',linestyle='',markersize=20)

# %% [markdown]
# # alpha property to control transparency of line chart

# %%
plt.plot(x,y,'g<',alpha=0.5) # alpha can be specified on a scale 0 to 1

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.plot(days, max_t)
plt.plot(days, min_t)
plt.plot(days, avg_t)

# %% [markdown]
# # Axes labels and chart title

# %%
# set axes labels and chart title
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')


plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average");

# %% [markdown]
# # Legend

# %%
# Show legend
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend();

# %%
# Legend at different location with shadow enabled and fontsize set to large
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(loc='upper right',shadow=True,fontsize='large')

# %% [markdown]
# # Grid

# %%
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(loc='best', fontsize="small",shadow=True)

plt.grid()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Functional Method

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]

salary = [38496, 42000, 46752, 49320, 53200, 56000, 62316, 64928, 67317, 68748, 73752]

# %%
salary_2 = [45372, 48876, 53850, 57287, 63016,65998, 70003, 70000, 71496, 75370, 83640]

# %% [markdown]
# plt.subplot(2,1,1)
# plt.plot(x1, y1)
# plt.subplot(2,1,2)
# plt.plot(x2, y2)

# %%
plt.subplot(2,1,1)
plt.plot(age,salary, "r") 
plt.subplot(2,1,2)
plt.plot(age,salary_2, "b");

# %% [markdown]
# # Object-Oritented Method

# %% [markdown]
# fig,axes=plt.subplots(1,2)       or
# fig,axes=plt.subplots(nrows=1,ncols=2)
# axes[].plot(x ,y)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(age, salary, "r")
ax[1].plot(age, salary_2, "g")
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  Matplotlib Styling vs code https://www.youtube.com/watch?v=Xsl-O7F-t4I&t=471s

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 5, 11)
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(x, x+13, color="green", lw=3, ls='-', marker='o', markersize=10)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0, 5, 11)
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(x, x+13, color="green", lw=3, ls='-', marker='o', markersize=10)
ax.set_xlim([0, 3])
ax.set_ylim([13, 16])
# Out:
# (13.0, 16.0)

# %%
# import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 5, 11)
fig, axes = plt.subplots()    
axes.plot(x, x**2, label="square")
axes.plot(x, x**3, label="cube")
axes.legend()
fig.savefig("square_cube.png")

# %% [markdown]
# # Bar Chart

# %% [markdown]
# #### matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, align='center', data=None)

# %% [markdown]
# ## Simple bar chart showing revenues of major US tech companies

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]

# %%
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue, label="Revenue")
plt.xticks(xpos,company)

plt.xlabel("Company")
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')

plt.legend()

# %% [markdown]
# ## Multiple Bars showing revenue and profit of major US tech companies

# %%
profit=[40,2,34,12]

# %%
plt.bar(xpos-0.2,revenue, width=0.4, label="Revenue")
plt.bar(xpos+0.2,profit, width=0.4,label="Profit")

plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()
plt.show()

# %% [markdown]
# # Horizontal bar chart using barh function

# %%
plt.barh(xpos,revenue, label="Revenue")

plt.yticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technolog Stocks')
plt.legend()

# %%
plt.barh(xpos-0.2,revenue, height=0.4, label="Revenue")
plt.barh(xpos+0.2,profit, height=0.4,label="Profit")

plt.yticks(xpos,company)
plt.xlabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# matplotlib.pyplot.hist(x, bins=None, range=None, density=False,
# orientation='vertical', color=None, label=None, stacked=False,data=None)

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar, bins=3, rwidth=0.95, color='g') #histtype='step'
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([blood_sugar_men,blood_sugar_women], bins=3, rwidth=0.95, color=['green','orange']) #histtype='step'
plt.legend();
# Out:
# No handles with labels found to put in legend.

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
plt.xlabel('szgar range')
plt.ylabel('total no of patients')
plt.title('Blood sugar analysis')
plt.hist([blood_sugar_men,blood_sugar_women], bins=3, rwidth=0.95, color=['green','orange'], label=['men','women']) #histtype='step'
plt.legend();

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
plt.xlabel('szgar range')
plt.ylabel('total no of patients')
plt.title('Blood sugar analysis')
plt.hist([blood_sugar_men,blood_sugar_women], bins=3, rwidth=0.95, color=['green','orange'],
         label=['men','women'],orientation='horizontal') #histtype='step'
plt.legend();

# %% [markdown]
# # Pie Chart

# %% [markdown]
# matplotlib.pyplot.pie(x, explode=None, labels=None, colors=None, autopct=None,
# pctdistance=0.6, labeldistance=1.1, startangle=0, radius=1, data=None)

# %% [markdown]
# ## Draw pie chart to track down home expenses

# %%
exp_vals = [1400, 600, 300, 410, 250]
exp_labels = ['Home Rent','Food','phone/Internet Bill','Car','Other Utilities']

# %%
plt.pie(exp_vals,labels=exp_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x18077295220>,
#   <matplotlib.patches.Wedge at 0x18077295760>,
#   <matplotlib.patches.Wedge at 0x18077295c40>,
#   <matplotlib.patches.Wedge at 0x180772a2160>,
#   <matplotlib.patches.Wedge at 0x180772a2640>],
#  [Text(0.09328656407206024, 1.0960372333838069, 'Home Rent'),
#   Text(-0.9822184890776084, -0.4952240298229684, 'Food'),
#   Text(-0.16284704617934698, -1.0878790555712807, 'phone/Internet Bill'),
#   Text(0.6256100334857941, -0.9047718419590123, 'Car'),
#   Text(1.0615045230766318, -0.28845822485734873, 'Other Utilities')])

# %% [markdown]
# ## Draw pie chart as perfect circle

# %%
plt.pie(exp_vals,labels=exp_labels, shadow=True)
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Show percentages for every pie. Specify radius to increase chart size

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5)
plt.show()

# %% [markdown]
# ## Explode

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.2])
plt.show()

# %% [markdown]
# ## counterclock and angle properties

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.2],counterclock=True, startangle=90)
plt.show()
